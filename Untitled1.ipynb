# %% [markdown]
# <a href="https://colab.research.google.com/github/ernesth010/Discord-project/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import numpy
# from scipy import stats
# speed = [99,96,87,88,111,86,103,87,96,78,77,85,86]
# x = numpy.mean(speed)
# print(x)
# x = numpy.median(speed)
# print(x)
# x = stats.mode(speed)
# # print(x)

# import numpy
# speed = [99,96,87,88,111,86,103,87,96,78,77,85,86]
# speedb = [32,111,138,28,59,77,97]
# x = numpy.std(speed)
# print(x)
# x = numpy.var(speed)
# print(x)
# x = numpy.std(speedb)
# print(x)
# x = numpy.var(speedb)
# print(x)
#

#  import numpy
# ages = [9,31,23,48,74,63,7,6,7,445,67,38,65]
# x = numpy.percentile (ages, q=75)
# print(x)

# import numpy as np
# import matplotlib.pyplot as plt
# x =np.random.uniform(low =0.0,high=5.0, size=250)
# plt.hist(x, bars =10)
# plt.show()

# import numpy
# import matplotlib.pyplot as plt
# x = numpy.random.normal(loc = 5.0, scale = 1.0, size = 10000)

# plt.hist(x, bins = 100)
# plt.show()

# import matplotlib.pyplot as plt
# x = [5,7,8,7,3,17, 9,6,12,9,11]
# y = [99,86,87,88,111,86,103,87,77,86,85,99]
# plt.scatter(x,y)
# plt.show()

import numpy as np
import matplotlib.pyplot as plt
x = numpy.random.normal(loc=5.0, scale=1.0, size=10000)
y = numpy.random.normal(loc=10.0, scale=2.0, size=10000)
plt.scatter(x,y)
plt.shpow()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3518345919.py in <cell line: 0>()
#      51 y = numpy.random.normal(loc=10.0, scale=2.0, size=10000)
#      52 plt.scatter(x,y)
# ---> 53 plt.shpow()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'shpow'
